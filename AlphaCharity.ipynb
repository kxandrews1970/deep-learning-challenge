# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)
application_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\kxand\AppData\Local\Temp\4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code (23).zip.245\Starter_Code\Starter_Code.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> application_df
#
# File c:\Users\kxand\.conda\envs\dev\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\kxand\.conda\envs\dev\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\kxand\.conda\envs\dev\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\kxand\.conda\envs\dev\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\kxand\.conda\envs\dev\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\kxand\.conda\envs\dev\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['EIN', 'NAME'] not found in axis"

# %%
# Determine the number of unique values in each column.
app_cat = application_df.dtypes.index.tolist()
application_df[app_cat].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df['APPLICATION_TYPE'].value_counts()
app_type_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

application_types_to_replace = list(app_type_count[app_type_count < 600].index)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df['CLASSIFICATION'].value_counts()
class_count.head(20)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count_gt1 = class_count.loc[class_count > 1]
class_count_gt1.head()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 500].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_app_df = pd.get_dummies(application_df)
numeric_app_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 53 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_app_df["IS_SUCCESSFUL"]
X = numeric_app_df.drop(["IS_SUCCESSFUL"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 9
hidden_nodes_layer2 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 9)                 396
#
#  dense_8 (Dense)             (None, 18)                180
#
#  dense_9 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 595 (2.32 KB)
# Trainable params: 595 (2.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5967 - accuracy: 0.7020
# Epoch 2/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5578 - accuracy: 0.7271
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5537 - accuracy: 0.7289
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5521 - accuracy: 0.7292
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5511 - accuracy: 0.7306
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5503 - accuracy: 0.7303
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5493 - accuracy: 0.7322
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5493 - accuracy: 0.7322
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5486 - accuracy: 0.7319
# Epoch 10/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5480 - accuracy: 0.7329
# Epoch 11/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5479 - accuracy: 0.7321
# Epoch 12/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5473 - accuracy: 0.7324
# Epoch 13/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5472 - accuracy: 0.7334
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5471 - accuracy: 0.7332
# Epoch 15/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5469 - accuracy: 0.7334
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5465 - accuracy: 0.7335
# Epoch 17/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5464 - accuracy: 0.7331
# Epoch 18/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5459 - accuracy: 0.7339
# Epoch 19/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5460 - accuracy: 0.7336
# Epoch 20/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5457 - accuracy: 0.7335
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7337
# Epoch 23/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7346
# Epoch 24/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7331
# Epoch 25/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5455 - accuracy: 0.7341
# Epoch 26/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5452 - accuracy: 0.7346
# Epoch 27/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5454 - accuracy: 0.7338
# Epoch 28/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5452 - accuracy: 0.7342
# Epoch 29/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5450 - accuracy: 0.7334
# Epoch 30/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5450 - accuracy: 0.7341
# Epoch 31/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5449 - accuracy: 0.7341
# Epoch 32/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5447 - accuracy: 0.7342
# Epoch 33/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5449 - accuracy: 0.7343
# Epoch 34/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5445 - accuracy: 0.7346
# Epoch 35/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5446 - accuracy: 0.7341
# Epoch 36/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5441 - accuracy: 0.7348
# Epoch 37/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5445 - accuracy: 0.7350
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5441 - accuracy: 0.7352
# Epoch 39/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5441 - accuracy: 0.7344
# Epoch 40/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5443 - accuracy: 0.7352
# Epoch 41/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5440 - accuracy: 0.7345
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7353
# Epoch 43/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7351
# Epoch 44/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5440 - accuracy: 0.7350
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5439 - accuracy: 0.7336
# Epoch 46/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7348
# Epoch 47/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5438 - accuracy: 0.7346
# Epoch 48/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7339
# Epoch 49/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5433 - accuracy: 0.7349
# Epoch 50/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5437 - accuracy: 0.7340
# Epoch 51/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5435 - accuracy: 0.7345
# Epoch 52/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5434 - accuracy: 0.7347
# Epoch 53/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5430 - accuracy: 0.7345
# Epoch 54/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7341
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5432 - accuracy: 0.7346
# Epoch 56/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5434 - accuracy: 0.7352
# Epoch 57/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5430 - accuracy: 0.7338
# Epoch 58/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7349
# Epoch 59/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5429 - accuracy: 0.7353
# Epoch 60/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5430 - accuracy: 0.7344
# Epoch 61/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5426 - accuracy: 0.7357
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5428 - accuracy: 0.7351
# Epoch 63/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5427 - accuracy: 0.7349
# Epoch 64/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5427 - accuracy: 0.7357
# Epoch 65/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5426 - accuracy: 0.7353
# Epoch 66/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5430 - accuracy: 0.7346
# Epoch 67/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5426 - accuracy: 0.7359
# Epoch 68/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5426 - accuracy: 0.7348
# Epoch 69/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7364
# Epoch 70/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5427 - accuracy: 0.7359
# Epoch 71/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5423 - accuracy: 0.7353
# Epoch 72/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5425 - accuracy: 0.7357
# Epoch 73/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5423 - accuracy: 0.7352
# Epoch 74/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5421 - accuracy: 0.7360
# Epoch 75/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5423 - accuracy: 0.7360
# Epoch 76/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5420 - accuracy: 0.7356
# Epoch 77/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5424 - accuracy: 0.7353
# Epoch 78/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5420 - accuracy: 0.7357
# Epoch 79/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5424 - accuracy: 0.7353
# Epoch 80/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5420 - accuracy: 0.7357
# Epoch 81/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5422 - accuracy: 0.7362
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5419 - accuracy: 0.7359
# Epoch 83/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5420 - accuracy: 0.7361
# Epoch 84/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5418 - accuracy: 0.7358
# Epoch 85/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5418 - accuracy: 0.7364
# Epoch 86/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5420 - accuracy: 0.7366
# Epoch 87/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5419 - accuracy: 0.7359
# Epoch 88/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5418 - accuracy: 0.7372
# Epoch 89/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5414 - accuracy: 0.7369
# Epoch 90/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5419 - accuracy: 0.7364
# Epoch 91/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5416 - accuracy: 0.7366
# Epoch 92/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5415 - accuracy: 0.7370
# Epoch 93/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5417 - accuracy: 0.7375
# Epoch 94/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5416 - accuracy: 0.7365
# Epoch 95/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7375
# Epoch 96/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7361
# Epoch 97/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5408 - accuracy: 0.7371
# Epoch 98/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5415 - accuracy: 0.7364
# Epoch 99/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7368
# Epoch 100/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5411 - accuracy: 0.7374

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5500 - accuracy: 0.7271 - 883ms/epoch - 3ms/step
# Loss: 0.5500220060348511, Accuracy: 0.7271137237548828

# %%
# plotting the accuracy
history_df = pd.DataFrame(fit_model.history, index = range(1, len(fit_model.history['loss'])+1))
history_df.plot(y = 'accuracy')
# Out:
# <Axes: >

# %%
# Export our model to HDF5 file
filename = '\AlphabetSoupCharity1.h5'
nn.model.save(filename)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\kxand\AppData\Local\Temp\4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code (23).zip.245\Starter_Code\Starter_Code.ipynb Cell 19 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # Export our model to HDF5 file
#       <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> filename = '\AlphabetSoupCharity1.h5'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> nn.model.save(filename)
#
# AttributeError: 'Sequential' object has no attribute 'model'

# %%
# Define the 2nd model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = X_train_scaled.shape[1]
# X shape/ input feature/columns is 43 * 2 is 86 so chose 80 for the first hidden node
hidden_node1 = 90
hidden_node2 = 30
# Add a third hidden layer
hidden_node3 = 20

nn_model_2 = tf.keras.models.Sequential()

# First hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=hidden_node1, activation='tanh', input_dim=input_features,))

# Second hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=hidden_node2, activation='tanh'))

# Third hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=hidden_node3, activation='tanh'))


# Output layer (output is 1 and sigmoid because it's binary classifier)
nn_model_2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn_model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 90)                3960
#
#  dense_4 (Dense)             (None, 30)                2730
#
#  dense_5 (Dense)             (None, 20)                620
#
#  dense_6 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 7331 (28.64 KB)
# Trainable params: 7331 (28.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the  2nd model
nn_model_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the 2nd model
fit_model_2 = nn_model_2.fit(X_train_scaled, y_train, epochs=50,callbacks=[cp_callback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\kxand\AppData\Local\Temp\4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code (23).zip.245\Starter_Code\Starter_Code.ipynb Cell 21 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Train the 2nd model
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kxand/AppData/Local/Temp/4583da77-8e5e-43e5-a7c3-a1018cbf1245_Starter_Code%20%2823%29.zip.245/Starter_Code/Starter_Code.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> fit_model_2 = nn_model_2.fit(X_train_scaled, y_train, epochs=50,callbacks=[cp_callback])
#
# NameError: name 'cp_callback' is not defined
